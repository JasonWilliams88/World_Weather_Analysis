# %%
import pandas as pd
import requests
from citipy import citipy
import numpy as np
from config import weather_api_key
from datetime import datetime
import time
import matplotlib.pyplot as plt
import json

# %%
# Create a set of random latitude and longitude combinations.
#zip pairs them
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# create a list to hold the unique cities
cities = []

# find the nearest city for each lng and lat
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Avoid adding duplicates by checking for dups and appending when unique
    if city not in cities:
        cities.append(city)
        
# amount of cities
len(cities)
# Out:
# 741

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2afbc27f9442a8aebf208c1ccd7a97d2

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_cond = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Conditions": city_cond,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 1 | misheronskiy
# Processing Record 3 of Set 1 | verbivka
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | tiksi
# Processing Record 7 of Set 1 | sao filipe
# Processing Record 8 of Set 1 | upernavik
# Processing Record 9 of Set 1 | novoagansk
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | aktau
# Processing Record 13 of Set 1 | chokurdakh
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | wad rawah
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | ust-tsilma
# Processing Record 19 of Set 1 | touros
# Processing Record 20 of Set 1 | smithers
# Processing Record 21 of Set 1 | bambous virieux
# Processing Record 22 of Set 1 | raudeberg
# Processing Record 23 of Set 1 | varciorog
# Processing Record 24 of Set 1 | sorland
# Processing Record 25 of Set 1 | saint george
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | tete
# Processing Record 28 of Set 1 | luganville
# Processing Record 29 of Set 1 | cockburn town
# Processing Record 30 of Set 1 | kalomo
# City not found. Skipping...
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | tateyama
# Processing Record 33 of Set 1 | manakara
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | sadon
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | saint-augustin
# Processing Record 38 of Set 1 | clyde river
# Processing Record 39 of Set 1 | grindavik
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | lahaina
# Processing Record 43 of Set 1 | chuy
# Processing Record 44 of Set 1 | georgetown
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | lahij
# Processing Record 47 of Set 1 | san antonio
# Processing Record 48 of Set 1 | airai
# Processing Record 49 of Set 1 | riyadh
# Processing Record 50 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | kahului
# Processing Record 4 of Set 2 | valparaiso
# Processing Record 5 of Set 2 | avera
# Processing Record 6 of Set 2 | tuktoyaktuk
# Processing Record 7 of Set 2 | huarmey
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 2 | alice springs
# Processing Record 11 of Set 2 | xichang
# Processing Record 12 of Set 2 | de aar
# Processing Record 13 of Set 2 | kutum
# Processing Record 14 of Set 2 | nome
# Processing Record 15 of Set 2 | shalyhyne
# Processing Record 16 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 2 | mishelevka
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | humaita
# Processing Record 22 of Set 2 | khani
# Processing Record 23 of Set 2 | bay city
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | ponta do sol
# Processing Record 26 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 2 | maiduguri
# Processing Record 28 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 2 | bereda
# Processing Record 30 of Set 2 | severo-kurilsk
# Processing Record 31 of Set 2 | poum
# Processing Record 32 of Set 2 | bac lieu
# Processing Record 33 of Set 2 | faanui
# Processing Record 34 of Set 2 | megion
# Processing Record 35 of Set 2 | bluff
# Processing Record 36 of Set 2 | bengkulu
# Processing Record 37 of Set 2 | carnarvon
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 2 | thompson
# Processing Record 41 of Set 2 | chapais
# Processing Record 42 of Set 2 | qom
# Processing Record 43 of Set 2 | port elizabeth
# Processing Record 44 of Set 2 | torbay
# Processing Record 45 of Set 2 | husavik
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | the valley
# Processing Record 48 of Set 2 | cherskiy
# Processing Record 49 of Set 2 | morro bay
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | sun prairie
# Processing Record 2 of Set 3 | namasuba
# Processing Record 3 of Set 3 | santa rosa
# Processing Record 4 of Set 3 | bethel
# Processing Record 5 of Set 3 | mehran
# Processing Record 6 of Set 3 | eastlake
# Processing Record 7 of Set 3 | estevan
# Processing Record 8 of Set 3 | saskylakh
# Processing Record 9 of Set 3 | jinka
# Processing Record 10 of Set 3 | llanes
# Processing Record 11 of Set 3 | port lincoln
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | general roca
# Processing Record 14 of Set 3 | villazon
# Processing Record 15 of Set 3 | new norfolk
# Processing Record 16 of Set 3 | vila velha
# Processing Record 17 of Set 3 | inhambane
# Processing Record 18 of Set 3 | faya
# Processing Record 19 of Set 3 | labuhan
# Processing Record 20 of Set 3 | talnakh
# Processing Record 21 of Set 3 | pangai
# Processing Record 22 of Set 3 | delijan
# Processing Record 23 of Set 3 | guerrero negro
# Processing Record 24 of Set 3 | lata
# Processing Record 25 of Set 3 | makakilo city
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | norman wells
# Processing Record 28 of Set 3 | qaanaaq
# Processing Record 29 of Set 3 | nakamura
# Processing Record 30 of Set 3 | ribeira grande
# Processing Record 31 of Set 3 | geraldton
# Processing Record 32 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 3 | pyapon
# Processing Record 34 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 3 | bamnet narong
# Processing Record 36 of Set 3 | springbok
# Processing Record 37 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 3 | bose
# Processing Record 39 of Set 3 | clovis
# Processing Record 40 of Set 3 | marshall
# Processing Record 41 of Set 3 | mar del plata
# Processing Record 42 of Set 3 | college
# Processing Record 43 of Set 3 | ilulissat
# Processing Record 44 of Set 3 | kaitangata
# Processing Record 45 of Set 3 | leningradskiy
# Processing Record 46 of Set 3 | najran
# Processing Record 47 of Set 3 | hermanus
# Processing Record 48 of Set 3 | adrar
# Processing Record 49 of Set 3 | ati
# Processing Record 50 of Set 3 | piney green
# Processing Record 1 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 4 | gazanjyk
# Processing Record 3 of Set 4 | antofagasta
# Processing Record 4 of Set 4 | saint-pierre
# Processing Record 5 of Set 4 | komsomolskiy
# Processing Record 6 of Set 4 | dingle
# Processing Record 7 of Set 4 | vao
# Processing Record 8 of Set 4 | westport
# Processing Record 9 of Set 4 | bathsheba
# Processing Record 10 of Set 4 | madimba
# Processing Record 11 of Set 4 | viedma
# Processing Record 12 of Set 4 | bagn
# Processing Record 13 of Set 4 | pilot butte
# Processing Record 14 of Set 4 | hithadhoo
# Processing Record 15 of Set 4 | biak
# Processing Record 16 of Set 4 | kiliya
# Processing Record 17 of Set 4 | mindelo
# Processing Record 18 of Set 4 | antalaha
# Processing Record 19 of Set 4 | nhulunbuy
# Processing Record 20 of Set 4 | mosquera
# Processing Record 21 of Set 4 | avarua
# Processing Record 22 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 4 | kununurra
# Processing Record 24 of Set 4 | sjovegan
# Processing Record 25 of Set 4 | lebu
# Processing Record 26 of Set 4 | teonthar
# Processing Record 27 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 4 | castro
# Processing Record 29 of Set 4 | russell
# Processing Record 30 of Set 4 | goldsboro
# Processing Record 31 of Set 4 | matara
# Processing Record 32 of Set 4 | portland
# Processing Record 33 of Set 4 | malinovoye ozero
# Processing Record 34 of Set 4 | honningsvag
# Processing Record 35 of Set 4 | fougeres
# Processing Record 36 of Set 4 | nanortalik
# Processing Record 37 of Set 4 | lagoa
# Processing Record 38 of Set 4 | emerald
# Processing Record 39 of Set 4 | ballina
# Processing Record 40 of Set 4 | constitucion
# Processing Record 41 of Set 4 | zheleznodorozhnyy
# Processing Record 42 of Set 4 | kruisfontein
# Processing Record 43 of Set 4 | hasaki
# Processing Record 44 of Set 4 | olafsvik
# Processing Record 45 of Set 4 | lakeway
# Processing Record 46 of Set 4 | andenes
# Processing Record 47 of Set 4 | madisonville
# Processing Record 48 of Set 4 | zhitikara
# City not found. Skipping...
# Processing Record 49 of Set 4 | soe
# Processing Record 50 of Set 4 | artyom
# Processing Record 1 of Set 5 | vardo
# Processing Record 2 of Set 5 | caraquet
# Processing Record 3 of Set 5 | alofi
# Processing Record 4 of Set 5 | hobyo
# Processing Record 5 of Set 5 | tocopilla
# Processing Record 6 of Set 5 | yarada
# Processing Record 7 of Set 5 | northam
# Processing Record 8 of Set 5 | souillac
# Processing Record 9 of Set 5 | balkanabat
# Processing Record 10 of Set 5 | bredasdorp
# Processing Record 11 of Set 5 | sarangani
# Processing Record 12 of Set 5 | korgen
# Processing Record 13 of Set 5 | ixtapa
# Processing Record 14 of Set 5 | tuatapere
# Processing Record 15 of Set 5 | sevlievo
# Processing Record 16 of Set 5 | sao joao da barra
# Processing Record 17 of Set 5 | ulaangom
# Processing Record 18 of Set 5 | bowen
# Processing Record 19 of Set 5 | christchurch
# Processing Record 20 of Set 5 | dikson
# Processing Record 21 of Set 5 | zolotinka
# City not found. Skipping...
# Processing Record 22 of Set 5 | jardim
# Processing Record 23 of Set 5 | provideniya
# Processing Record 24 of Set 5 | hauterive
# Processing Record 25 of Set 5 | beyneu
# Processing Record 26 of Set 5 | winslow
# Processing Record 27 of Set 5 | klaksvik
# Processing Record 28 of Set 5 | ahuimanu
# Processing Record 29 of Set 5 | burnie
# Processing Record 30 of Set 5 | taos
# Processing Record 31 of Set 5 | atambua
# Processing Record 32 of Set 5 | haines junction
# Processing Record 33 of Set 5 | srivardhan
# Processing Record 34 of Set 5 | atar
# Processing Record 35 of Set 5 | majene
# Processing Record 36 of Set 5 | dzaoudzi
# Processing Record 37 of Set 5 | merritt island
# Processing Record 38 of Set 5 | lompoc
# Processing Record 39 of Set 5 | jiroft
# City not found. Skipping...
# Processing Record 40 of Set 5 | lorengau
# Processing Record 41 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 5 | minbu
# Processing Record 44 of Set 5 | babayurt
# Processing Record 45 of Set 5 | bollnas
# Processing Record 46 of Set 5 | muros
# Processing Record 47 of Set 5 | orange
# Processing Record 48 of Set 5 | great yarmouth
# Processing Record 49 of Set 5 | rizhao
# Processing Record 50 of Set 5 | vila do maio
# Processing Record 1 of Set 6 | pevek
# Processing Record 2 of Set 6 | tecoanapa
# Processing Record 3 of Set 6 | muscat
# Processing Record 4 of Set 6 | coihueco
# Processing Record 5 of Set 6 | batemans bay
# Processing Record 6 of Set 6 | hami
# Processing Record 7 of Set 6 | gravelbourg
# Processing Record 8 of Set 6 | praia
# Processing Record 9 of Set 6 | maceio
# Processing Record 10 of Set 6 | lityn
# Processing Record 11 of Set 6 | yulara
# Processing Record 12 of Set 6 | ancud
# Processing Record 13 of Set 6 | sungaipenuh
# Processing Record 14 of Set 6 | marzuq
# Processing Record 15 of Set 6 | lithakia
# Processing Record 16 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 6 | priiskovyy
# Processing Record 18 of Set 6 | tabou
# Processing Record 19 of Set 6 | damaturu
# Processing Record 20 of Set 6 | syracuse
# Processing Record 21 of Set 6 | yima
# Processing Record 22 of Set 6 | opunake
# Processing Record 23 of Set 6 | saldanha
# Processing Record 24 of Set 6 | okha
# Processing Record 25 of Set 6 | opuwo
# Processing Record 26 of Set 6 | zhuhai
# Processing Record 27 of Set 6 | bosaso
# Processing Record 28 of Set 6 | grand gaube
# Processing Record 29 of Set 6 | kamaishi
# Processing Record 30 of Set 6 | korla
# Processing Record 31 of Set 6 | homburg
# Processing Record 32 of Set 6 | nizhniy odes
# Processing Record 33 of Set 6 | lasa
# Processing Record 34 of Set 6 | tasiilaq
# Processing Record 35 of Set 6 | hay river
# Processing Record 36 of Set 6 | mount isa
# Processing Record 37 of Set 6 | gambela
# Processing Record 38 of Set 6 | tefe
# Processing Record 39 of Set 6 | ugoofaaru
# Processing Record 40 of Set 6 | arraial do cabo
# Processing Record 41 of Set 6 | jasper
# Processing Record 42 of Set 6 | perm
# Processing Record 43 of Set 6 | strezhevoy
# Processing Record 44 of Set 6 | robertsganj
# Processing Record 45 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 46 of Set 6 | koulikoro
# Processing Record 47 of Set 6 | coracao de jesus
# Processing Record 48 of Set 6 | corinto
# Processing Record 49 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 6 | oranjestad
# Processing Record 1 of Set 7 | chlorakas
# Processing Record 2 of Set 7 | tsimlyansk
# Processing Record 3 of Set 7 | virginia beach
# Processing Record 4 of Set 7 | katsuura
# Processing Record 5 of Set 7 | pedernales
# Processing Record 6 of Set 7 | hambantota
# Processing Record 7 of Set 7 | praia da vitoria
# Processing Record 8 of Set 7 | cidreira
# Processing Record 9 of Set 7 | morros
# Processing Record 10 of Set 7 | asyut
# Processing Record 11 of Set 7 | los llanos de aridane
# Processing Record 12 of Set 7 | rajmahal
# Processing Record 13 of Set 7 | yinchuan
# Processing Record 14 of Set 7 | dok kham tai
# Processing Record 15 of Set 7 | shache
# Processing Record 16 of Set 7 | mersing
# Processing Record 17 of Set 7 | sisimiut
# Processing Record 18 of Set 7 | udachnyy
# Processing Record 19 of Set 7 | mackay
# Processing Record 20 of Set 7 | uarini
# Processing Record 21 of Set 7 | mugumu
# Processing Record 22 of Set 7 | pontianak
# Processing Record 23 of Set 7 | port-gentil
# Processing Record 24 of Set 7 | vestmannaeyjar
# Processing Record 25 of Set 7 | roebourne
# Processing Record 26 of Set 7 | kharod
# Processing Record 27 of Set 7 | mahebourg
# Processing Record 28 of Set 7 | muroto
# Processing Record 29 of Set 7 | deputatskiy
# Processing Record 30 of Set 7 | tura
# Processing Record 31 of Set 7 | san patricio
# Processing Record 32 of Set 7 | turukhansk
# Processing Record 33 of Set 7 | grafenhainichen
# Processing Record 34 of Set 7 | bere
# Processing Record 35 of Set 7 | fortuna
# Processing Record 36 of Set 7 | ostrovnoy
# Processing Record 37 of Set 7 | sembakung
# Processing Record 38 of Set 7 | lazaro cardenas
# Processing Record 39 of Set 7 | tahoua
# Processing Record 40 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 7 | tonantins
# Processing Record 42 of Set 7 | ingham
# Processing Record 43 of Set 7 | fare
# Processing Record 44 of Set 7 | cabo san lucas
# Processing Record 45 of Set 7 | vestmanna
# Processing Record 46 of Set 7 | banda aceh
# Processing Record 47 of Set 7 | san clemente
# Processing Record 48 of Set 7 | sondrio
# Processing Record 49 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 50 of Set 7 | lipany
# Processing Record 1 of Set 8 | beringovskiy
# Processing Record 2 of Set 8 | jitra
# Processing Record 3 of Set 8 | taltal
# Processing Record 4 of Set 8 | zhicheng
# Processing Record 5 of Set 8 | mayahi
# Processing Record 6 of Set 8 | comodoro rivadavia
# Processing Record 7 of Set 8 | porto novo
# Processing Record 8 of Set 8 | rawson
# Processing Record 9 of Set 8 | maarianhamina
# Processing Record 10 of Set 8 | wasilla
# Processing Record 11 of Set 8 | mahaicony
# City not found. Skipping...
# Processing Record 12 of Set 8 | esperance
# Processing Record 13 of Set 8 | port moresby
# Processing Record 14 of Set 8 | aklavik
# Processing Record 15 of Set 8 | erdenet
# Processing Record 16 of Set 8 | namibe
# Processing Record 17 of Set 8 | ornskoldsvik
# Processing Record 18 of Set 8 | vila franca do campo
# Processing Record 19 of Set 8 | tecpan
# Processing Record 20 of Set 8 | vangaindrano
# Processing Record 21 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 22 of Set 8 | havoysund
# Processing Record 23 of Set 8 | zyryanka
# Processing Record 24 of Set 8 | saint-joseph
# Processing Record 25 of Set 8 | mapiripan
# Processing Record 26 of Set 8 | mangrol
# Processing Record 27 of Set 8 | shieli
# Processing Record 28 of Set 8 | kargasok
# Processing Record 29 of Set 8 | nantucket
# Processing Record 30 of Set 8 | plaeng yao
# Processing Record 31 of Set 8 | mareeba
# Processing Record 32 of Set 8 | livingstonia
# Processing Record 33 of Set 8 | mudyuga
# City not found. Skipping...
# Processing Record 34 of Set 8 | bonavista
# Processing Record 35 of Set 8 | amapa
# Processing Record 36 of Set 8 | imbituba
# Processing Record 37 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 8 | yabelo
# Processing Record 39 of Set 8 | debar
# Processing Record 40 of Set 8 | peniche
# Processing Record 41 of Set 8 | dabrowa gornicza
# Processing Record 42 of Set 8 | chaupal
# Processing Record 43 of Set 8 | pinyug
# Processing Record 44 of Set 8 | atlantic city
# Processing Record 45 of Set 8 | rodeo
# Processing Record 46 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 8 | geilo
# Processing Record 48 of Set 8 | dudinka
# Processing Record 49 of Set 8 | kanigiri
# Processing Record 50 of Set 8 | kaoma
# Processing Record 1 of Set 9 | kudahuvadhoo
# Processing Record 2 of Set 9 | gimli
# Processing Record 3 of Set 9 | deloraine
# Processing Record 4 of Set 9 | dunedin
# Processing Record 5 of Set 9 | denpasar
# Processing Record 6 of Set 9 | cabucgayan
# Processing Record 7 of Set 9 | ternate
# Processing Record 8 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 9 | anderson
# Processing Record 10 of Set 9 | paciran
# Processing Record 11 of Set 9 | sirawai
# Processing Record 12 of Set 9 | pitimbu
# Processing Record 13 of Set 9 | bloemfontein
# Processing Record 14 of Set 9 | panama city
# Processing Record 15 of Set 9 | vila
# Processing Record 16 of Set 9 | sidney
# Processing Record 17 of Set 9 | ketchikan
# Processing Record 18 of Set 9 | angoche
# Processing Record 19 of Set 9 | ust-kuyga
# Processing Record 20 of Set 9 | paamiut
# Processing Record 21 of Set 9 | longyan
# Processing Record 22 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 23 of Set 9 | gazojak
# Processing Record 24 of Set 9 | bridlington
# Processing Record 25 of Set 9 | sitka
# Processing Record 26 of Set 9 | voh
# Processing Record 27 of Set 9 | pakxan
# Processing Record 28 of Set 9 | kalmunai
# Processing Record 29 of Set 9 | oskemen
# Processing Record 30 of Set 9 | micheweni
# Processing Record 31 of Set 9 | clermont
# Processing Record 32 of Set 9 | zhangjiakou
# Processing Record 33 of Set 9 | puerto madryn
# Processing Record 34 of Set 9 | sao borja
# Processing Record 35 of Set 9 | suntar
# Processing Record 36 of Set 9 | aswan
# Processing Record 37 of Set 9 | tartki
# City not found. Skipping...
# Processing Record 38 of Set 9 | naze
# Processing Record 39 of Set 9 | axim
# Processing Record 40 of Set 9 | poronaysk
# Processing Record 41 of Set 9 | armidale
# Processing Record 42 of Set 9 | cayenne
# Processing Record 43 of Set 9 | tiznit
# Processing Record 44 of Set 9 | galion
# Processing Record 45 of Set 9 | luderitz
# Processing Record 46 of Set 9 | pangnirtung
# Processing Record 47 of Set 9 | selty
# Processing Record 48 of Set 9 | ohara
# Processing Record 49 of Set 9 | dickinson
# Processing Record 50 of Set 9 | luklukan
# Processing Record 1 of Set 10 | broome
# Processing Record 2 of Set 10 | twin falls
# Processing Record 3 of Set 10 | vreed en hoop
# City not found. Skipping...
# Processing Record 4 of Set 10 | calabozo
# Processing Record 5 of Set 10 | dalbandin
# Processing Record 6 of Set 10 | ngunguru
# Processing Record 7 of Set 10 | iranshahr
# Processing Record 8 of Set 10 | lekoni
# Processing Record 9 of Set 10 | lumeje
# Processing Record 10 of Set 10 | pinega
# Processing Record 11 of Set 10 | victoria
# Processing Record 12 of Set 10 | lac du bonnet
# Processing Record 13 of Set 10 | ust-koksa
# Processing Record 14 of Set 10 | evensk
# Processing Record 15 of Set 10 | esso
# Processing Record 16 of Set 10 | witu
# Processing Record 17 of Set 10 | cervo
# Processing Record 18 of Set 10 | narsaq
# Processing Record 19 of Set 10 | bubaque
# Processing Record 20 of Set 10 | bemidji
# Processing Record 21 of Set 10 | fort nelson
# Processing Record 22 of Set 10 | asau
# Processing Record 23 of Set 10 | antsohihy
# Processing Record 24 of Set 10 | padang
# Processing Record 25 of Set 10 | fengrun
# Processing Record 26 of Set 10 | williston
# Processing Record 27 of Set 10 | parangan
# Processing Record 28 of Set 10 | chernyshevskiy
# Processing Record 29 of Set 10 | nouadhibou
# Processing Record 30 of Set 10 | mbini
# Processing Record 31 of Set 10 | yar-sale
# Processing Record 32 of Set 10 | nisia floresta
# Processing Record 33 of Set 10 | grand valley
# Processing Record 34 of Set 10 | kapuskasing
# Processing Record 35 of Set 10 | broken hill
# Processing Record 36 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 10 | palmer
# Processing Record 38 of Set 10 | shimanovsk
# Processing Record 39 of Set 10 | sarakhs
# Processing Record 40 of Set 10 | araouane
# Processing Record 41 of Set 10 | buraydah
# Processing Record 42 of Set 10 | sur
# Processing Record 43 of Set 10 | tutoia
# Processing Record 44 of Set 10 | sulina
# Processing Record 45 of Set 10 | biltine
# Processing Record 46 of Set 10 | olga
# Processing Record 47 of Set 10 | ostersund
# Processing Record 48 of Set 10 | maniitsoq
# Processing Record 49 of Set 10 | ahipara
# Processing Record 50 of Set 10 | tiruchchendur
# Processing Record 1 of Set 11 | tshela
# Processing Record 2 of Set 11 | nyurba
# Processing Record 3 of Set 11 | koster
# Processing Record 4 of Set 11 | santo domingo
# Processing Record 5 of Set 11 | shingu
# Processing Record 6 of Set 11 | sagua la grande
# Processing Record 7 of Set 11 | shakawe
# Processing Record 8 of Set 11 | itarema
# Processing Record 9 of Set 11 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 10 of Set 11 | altamira
# Processing Record 11 of Set 11 | tanout
# Processing Record 12 of Set 11 | mattawa
# Processing Record 13 of Set 11 | qui nhon
# Processing Record 14 of Set 11 | sumenep
# Processing Record 15 of Set 11 | oakland
# Processing Record 16 of Set 11 | kjollefjord
# Processing Record 17 of Set 11 | codrington
# Processing Record 18 of Set 11 | trofors
# Processing Record 19 of Set 11 | mudgee
# Processing Record 20 of Set 11 | belaguntha
# Processing Record 21 of Set 11 | homer
# Processing Record 22 of Set 11 | japura
# Processing Record 23 of Set 11 | borovoy
# Processing Record 24 of Set 11 | boralday
# Processing Record 25 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 11 | erzin
# Processing Record 27 of Set 11 | houma
# Processing Record 28 of Set 11 | ngaoundere
# Processing Record 29 of Set 11 | moissala
# Processing Record 30 of Set 11 | keflavik
# Processing Record 31 of Set 11 | shubarshi
# Processing Record 32 of Set 11 | alta floresta
# Processing Record 33 of Set 11 | buala
# Processing Record 34 of Set 11 | jennings
# Processing Record 35 of Set 11 | aguas formosas
# Processing Record 36 of Set 11 | pochutla
# Processing Record 37 of Set 11 | vilyuysk
# Processing Record 38 of Set 11 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 39 of Set 11 | kismayo
# Processing Record 40 of Set 11 | menongue
# Processing Record 41 of Set 11 | betioky
# Processing Record 42 of Set 11 | bara
# Processing Record 43 of Set 11 | muravlenko
# Processing Record 44 of Set 11 | miri
# Processing Record 45 of Set 11 | marsh harbour
# Processing Record 46 of Set 11 | rokytne
# Processing Record 47 of Set 11 | monrovia
# Processing Record 48 of Set 11 | ajaccio
# Processing Record 49 of Set 11 | hornepayne
# Processing Record 50 of Set 11 | mangai
# Processing Record 1 of Set 12 | bondoukou
# Processing Record 2 of Set 12 | phan thiet
# Processing Record 3 of Set 12 | haimen
# Processing Record 4 of Set 12 | chicama
# Processing Record 5 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 6 of Set 12 | kuminskiy
# Processing Record 7 of Set 12 | salekhard
# Processing Record 8 of Set 12 | henties bay
# Processing Record 9 of Set 12 | vostok
# Processing Record 10 of Set 12 | lexington park
# Processing Record 11 of Set 12 | lavumisa
# Processing Record 12 of Set 12 | ames
# Processing Record 13 of Set 12 | ferme-neuve
# Processing Record 14 of Set 12 | macapa
# Processing Record 15 of Set 12 | ariquemes
# Processing Record 16 of Set 12 | mendi
# Processing Record 17 of Set 12 | sabang
# Processing Record 18 of Set 12 | ramona
# Processing Record 19 of Set 12 | aparecida do taboado
# Processing Record 20 of Set 12 | hanko
# Processing Record 21 of Set 12 | seoul
# Processing Record 22 of Set 12 | lasem
# Processing Record 23 of Set 12 | bahia honda
# Processing Record 24 of Set 12 | burica
# City not found. Skipping...
# Processing Record 25 of Set 12 | kandrian
# Processing Record 26 of Set 12 | chacabuco
# Processing Record 27 of Set 12 | jackson
# Processing Record 28 of Set 12 | tautira
# Processing Record 29 of Set 12 | sibolga
# Processing Record 30 of Set 12 | sinnamary
# Processing Record 31 of Set 12 | fiumicino
# Processing Record 32 of Set 12 | allapalli
# Processing Record 33 of Set 12 | palmas bellas
# Processing Record 34 of Set 12 | buriti
# Processing Record 35 of Set 12 | buon me thuot
# City not found. Skipping...
# Processing Record 36 of Set 12 | staryy nadym
# Processing Record 37 of Set 12 | grants
# Processing Record 38 of Set 12 | andilamena
# Processing Record 39 of Set 12 | ulladulla
# Processing Record 40 of Set 12 | pizarro
# Processing Record 41 of Set 12 | beloha
# Processing Record 42 of Set 12 | cedar city
# Processing Record 43 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 44 of Set 12 | kenora
# Processing Record 45 of Set 12 | berlevag
# Processing Record 46 of Set 12 | port augusta
# Processing Record 47 of Set 12 | tilichiki
# Processing Record 48 of Set 12 | novogagatli
# Processing Record 49 of Set 12 | dustlik
# Processing Record 50 of Set 12 | charters towers
# Processing Record 1 of Set 13 | luena
# Processing Record 2 of Set 13 | tazovskiy
# Processing Record 3 of Set 13 | mogadishu
# Processing Record 4 of Set 13 | bandarbeyla
# Processing Record 5 of Set 13 | carauari
# Processing Record 6 of Set 13 | tumut
# Processing Record 7 of Set 13 | takoradi
# Processing Record 8 of Set 13 | margate
# Processing Record 9 of Set 13 | mount gambier
# Processing Record 10 of Set 13 | fairbanks
# Processing Record 11 of Set 13 | erenhot
# Processing Record 12 of Set 13 | gunnedah
# Processing Record 13 of Set 13 | axixa do tocantins
# City not found. Skipping...
# Processing Record 14 of Set 13 | chapleau
# Processing Record 15 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 16 of Set 13 | hwange
# Processing Record 17 of Set 13 | qasigiannguit
# Processing Record 18 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 19 of Set 13 | rio branco
# Processing Record 20 of Set 13 | uyemskiy
# Processing Record 21 of Set 13 | kapoeta
# Processing Record 22 of Set 13 | bima
# Processing Record 23 of Set 13 | halifax
# Processing Record 24 of Set 13 | patrocinio
# Processing Record 25 of Set 13 | bhuban
# Processing Record 26 of Set 13 | shenzhen
# Processing Record 27 of Set 13 | santa cruz
# Processing Record 28 of Set 13 | mandalgovi
# Processing Record 29 of Set 13 | laguna
# Processing Record 30 of Set 13 | aquiraz
# Processing Record 31 of Set 13 | papara
# Processing Record 32 of Set 13 | kavaratti
# Processing Record 33 of Set 13 | funtua
# Processing Record 34 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 13 | north bend
# Processing Record 36 of Set 13 | ginda
# Processing Record 37 of Set 13 | batticaloa
# Processing Record 38 of Set 13 | wangqing
# Processing Record 39 of Set 13 | shushenskoye
# Processing Record 40 of Set 13 | gazimurskiy zavod
# Processing Record 41 of Set 13 | ipiales
# Processing Record 42 of Set 13 | slave lake
# Processing Record 43 of Set 13 | sao miguel do araguaia
# Processing Record 44 of Set 13 | nelson bay
# Processing Record 45 of Set 13 | kendari
# Processing Record 46 of Set 13 | warrenton
# Processing Record 47 of Set 13 | mwandiga
# Processing Record 48 of Set 13 | shelburne
# Processing Record 49 of Set 13 | kasempa
# Processing Record 50 of Set 13 | altay
# Processing Record 1 of Set 14 | flinders
# Processing Record 2 of Set 14 | richards bay
# Processing Record 3 of Set 14 | huangnihe
# Processing Record 4 of Set 14 | lusambo
# Processing Record 5 of Set 14 | komsomolets
# Processing Record 6 of Set 14 | atbasar
# Processing Record 7 of Set 14 | bud
# Processing Record 8 of Set 14 | samarai
# Processing Record 9 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 10 of Set 14 | gat
# Processing Record 11 of Set 14 | kharp
# Processing Record 12 of Set 14 | surab
# Processing Record 13 of Set 14 | rome
# Processing Record 14 of Set 14 | te anau
# Processing Record 15 of Set 14 | srednekolymsk
# Processing Record 16 of Set 14 | pisco
# Processing Record 17 of Set 14 | ushtobe
# Processing Record 18 of Set 14 | shaunavon
# Processing Record 19 of Set 14 | mugur-aksy
# Processing Record 20 of Set 14 | balabac
# Processing Record 21 of Set 14 | fayaoue
# Processing Record 22 of Set 14 | zhuanghe
# Processing Record 23 of Set 14 | manubul
# Processing Record 24 of Set 14 | krasnoselkup
# Processing Record 25 of Set 14 | moose factory
# Processing Record 26 of Set 14 | sheregesh
# Processing Record 27 of Set 14 | prambanan
# City not found. Skipping...
# Processing Record 28 of Set 14 | abiy adi
# City not found. Skipping...
# Processing Record 29 of Set 14 | semenyih
# Processing Record 30 of Set 14 | gigmoto
# Processing Record 31 of Set 14 | ravar
# Processing Record 32 of Set 14 | hervey bay
# Processing Record 33 of Set 14 | rupert
# Processing Record 34 of Set 14 | vilhena
# Processing Record 35 of Set 14 | kirakira
# Processing Record 36 of Set 14 | havre-saint-pierre
# Processing Record 37 of Set 14 | camboriu
# City not found. Skipping...
# Processing Record 38 of Set 14 | barcelos
# Processing Record 39 of Set 14 | celestun
# Processing Record 40 of Set 14 | alihe
# Processing Record 41 of Set 14 | havelock
# Processing Record 42 of Set 14 | kozhanka
# Processing Record 43 of Set 14 | hailar
# Processing Record 44 of Set 14 | tessalit
# Processing Record 45 of Set 14 | namestovo
# Processing Record 46 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 14 | taraza
# Processing Record 48 of Set 14 | nishihara
# Processing Record 49 of Set 14 | coquimbo
# Processing Record 50 of Set 14 | enshi
# Processing Record 1 of Set 15 | coihaique
# Processing Record 2 of Set 15 | zemio
# Processing Record 3 of Set 15 | launceston
# Processing Record 4 of Set 15 | mombetsu
# Processing Record 5 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 6 of Set 15 | kavieng
# Processing Record 7 of Set 15 | whitianga
# Processing Record 8 of Set 15 | sumbe
# Processing Record 9 of Set 15 | manuk mangkaw
# Processing Record 10 of Set 15 | shostka
# Processing Record 11 of Set 15 | zhigansk
# Processing Record 12 of Set 15 | sale
# Processing Record 13 of Set 15 | bambanglipuro
# Processing Record 14 of Set 15 | mariental
# Processing Record 15 of Set 15 | zhezkazgan
# Processing Record 16 of Set 15 | beboto
# Processing Record 17 of Set 15 | wajima
# Processing Record 18 of Set 15 | toktogul
# Processing Record 19 of Set 15 | santiago del estero
# Processing Record 20 of Set 15 | chitrakonda
# Processing Record 21 of Set 15 | picota
# Processing Record 22 of Set 15 | santa ines
# Processing Record 23 of Set 15 | wasserburg
# Processing Record 24 of Set 15 | tornio
# Processing Record 25 of Set 15 | bocas del toro
# Processing Record 26 of Set 15 | ropczyce
# Processing Record 27 of Set 15 | new philadelphia
# Processing Record 28 of Set 15 | ucluelet
# Processing Record 29 of Set 15 | volchansk
# Processing Record 30 of Set 15 | progreso
# Processing Record 31 of Set 15 | wagar
# Processing Record 32 of Set 15 | kailua
# Processing Record 33 of Set 15 | sambava
# Processing Record 34 of Set 15 | umm kaddadah
# Processing Record 35 of Set 15 | abonnema
# Processing Record 36 of Set 15 | nipawin
# Processing Record 37 of Set 15 | qaqortoq
# Processing Record 38 of Set 15 | sal rei
# Processing Record 39 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 15 | yumen
# Processing Record 41 of Set 15 | boa vista
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 688

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Misheronskiy      RU  55.7193   39.7383      7.95        96          49
# 1      Verbivka      UA  49.4167   35.5333     36.72        97         100
# 2        Kodiak      US  57.7900 -152.4072     26.60        50           1
# 3  Punta Arenas      CL -53.1500  -70.9167     50.00        76           0
# 4         Tiksi      RU  71.6872  128.8694    -11.36        90         100
# 5    Sao Filipe      CV  14.8961  -24.4956     71.76        77           0
# 6     Upernavik      GL  72.7868  -56.1549     -4.86        90         100
# 7    Novoagansk      RU  61.9449   76.6625      7.07        94         100
# 8        Hobart      AU -42.8794  147.3294     70.00        39          75
# 9     Busselton      AU -33.6500  115.3333     88.12        31           0
#
#    Wind Speed Current Conditions
# 0        3.44   scattered clouds
# 1        2.55    overcast clouds
# 2       11.50          clear sky
# 3       34.52          clear sky
# 4       11.01         light snow
# 5       10.58          clear sky
# 6        7.14    overcast clouds
# 7       10.85         light snow
# 8       14.97      broken clouds
# 9        9.66          clear sky

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
