# %%
import pandas as pd
import requests
from citipy import citipy
import numpy as np
from config import weather_api_key
from datetime import datetime
import time
import matplotlib.pyplot as plt
import json

# %%
# Create a set of random latitude and longitude combinations.
#zip pairs them
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# create a list to hold the unique cities
cities = []

# find the nearest city for each lng and lat
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Avoid adding duplicates by checking for dups and appending when unique
    if city not in cities:
        cities.append(city)
        
# amount of cities
len(cities)
# Out:
# 755

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2afbc27f9442a8aebf208c1ccd7a97d2

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_cond = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Conditions": city_cond,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 1 | semenivka
# Processing Record 4 of Set 1 | palmer
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 1 | itanhandu
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | paka
# Processing Record 12 of Set 1 | sur
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | mount gambier
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 1 | bengkulu
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | nara
# Processing Record 22 of Set 1 | virginia beach
# Processing Record 23 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 1 | bronnoysund
# Processing Record 25 of Set 1 | cherskiy
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | iquique
# Processing Record 30 of Set 1 | chuy
# Processing Record 31 of Set 1 | buraydah
# Processing Record 32 of Set 1 | emerald
# Processing Record 33 of Set 1 | yashalta
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | biak
# Processing Record 36 of Set 1 | geraldton
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | launceston
# Processing Record 39 of Set 1 | laguna
# Processing Record 40 of Set 1 | pacific grove
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | luderitz
# Processing Record 43 of Set 1 | kaitangata
# Processing Record 44 of Set 1 | nikolskoye
# Processing Record 45 of Set 1 | diamantino
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | dalvik
# Processing Record 48 of Set 1 | poum
# Processing Record 49 of Set 1 | nosy varika
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | broome
# Processing Record 2 of Set 2 | cockburn town
# Processing Record 3 of Set 2 | faya
# Processing Record 4 of Set 2 | cabra
# Processing Record 5 of Set 2 | saskylakh
# Processing Record 6 of Set 2 | lompoc
# Processing Record 7 of Set 2 | kosa
# Processing Record 8 of Set 2 | horodnytsya
# Processing Record 9 of Set 2 | wattegama
# Processing Record 10 of Set 2 | leningradskiy
# Processing Record 11 of Set 2 | aklavik
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | inhambane
# Processing Record 14 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 2 | amalapuram
# Processing Record 16 of Set 2 | tasiilaq
# Processing Record 17 of Set 2 | kruisfontein
# Processing Record 18 of Set 2 | ewa beach
# Processing Record 19 of Set 2 | saint george
# Processing Record 20 of Set 2 | vardo
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 2 | harper
# Processing Record 24 of Set 2 | mahebourg
# Processing Record 25 of Set 2 | castro
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | durban
# Processing Record 29 of Set 2 | portland
# Processing Record 30 of Set 2 | luang prabang
# Processing Record 31 of Set 2 | pedernales
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | catalina
# Processing Record 34 of Set 2 | igarka
# Processing Record 35 of Set 2 | sao pedro da cadeira
# Processing Record 36 of Set 2 | kavieng
# Processing Record 37 of Set 2 | hailar
# Processing Record 38 of Set 2 | ciudad bolivar
# Processing Record 39 of Set 2 | yulara
# Processing Record 40 of Set 2 | prince rupert
# Processing Record 41 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 2 | ribeira grande
# Processing Record 43 of Set 2 | valparaiso
# Processing Record 44 of Set 2 | atuona
# Processing Record 45 of Set 2 | barrow
# Processing Record 46 of Set 2 | ginir
# Processing Record 47 of Set 2 | meulaboh
# Processing Record 48 of Set 2 | port hedland
# Processing Record 49 of Set 2 | hilo
# Processing Record 50 of Set 2 | grindavik
# Processing Record 1 of Set 3 | bloemfontein
# Processing Record 2 of Set 3 | lima
# Processing Record 3 of Set 3 | heze
# Processing Record 4 of Set 3 | manacapuru
# Processing Record 5 of Set 3 | katsuura
# Processing Record 6 of Set 3 | kitami
# Processing Record 7 of Set 3 | arraial do cabo
# Processing Record 8 of Set 3 | dwarka
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | auki
# Processing Record 11 of Set 3 | lata
# Processing Record 12 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 3 | santa cruz de la palma
# Processing Record 14 of Set 3 | srandakan
# Processing Record 15 of Set 3 | ketchikan
# Processing Record 16 of Set 3 | capao da canoa
# Processing Record 17 of Set 3 | juneau
# Processing Record 18 of Set 3 | iqaluit
# Processing Record 19 of Set 3 | naples
# Processing Record 20 of Set 3 | flinders
# Processing Record 21 of Set 3 | bredasdorp
# Processing Record 22 of Set 3 | naryan-mar
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | carnarvon
# Processing Record 25 of Set 3 | baijiantan
# Processing Record 26 of Set 3 | ostrovnoy
# Processing Record 27 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 3 | sandpoint
# Processing Record 29 of Set 3 | cayenne
# Processing Record 30 of Set 3 | pitimbu
# Processing Record 31 of Set 3 | ponta delgada
# Processing Record 32 of Set 3 | oussouye
# Processing Record 33 of Set 3 | margate
# Processing Record 34 of Set 3 | saint-augustin
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | thunder bay
# Processing Record 37 of Set 3 | blagoyevo
# Processing Record 38 of Set 3 | khatanga
# Processing Record 39 of Set 3 | vila franca do campo
# Processing Record 40 of Set 3 | saldanha
# Processing Record 41 of Set 3 | esperance
# Processing Record 42 of Set 3 | rosarito
# Processing Record 43 of Set 3 | ardistan
# City not found. Skipping...
# Processing Record 44 of Set 3 | zhirnovsk
# Processing Record 45 of Set 3 | handwara
# City not found. Skipping...
# Processing Record 46 of Set 3 | zhanakorgan
# Processing Record 47 of Set 3 | uong bi
# Processing Record 48 of Set 3 | nanortalik
# Processing Record 49 of Set 3 | tuatapere
# Processing Record 50 of Set 3 | kutum
# Processing Record 1 of Set 4 | bayir
# Processing Record 2 of Set 4 | waipawa
# Processing Record 3 of Set 4 | severo-kurilsk
# Processing Record 4 of Set 4 | cabo san lucas
# Processing Record 5 of Set 4 | hasaki
# Processing Record 6 of Set 4 | codrington
# Processing Record 7 of Set 4 | aktau
# Processing Record 8 of Set 4 | tukan
# Processing Record 9 of Set 4 | tuktoyaktuk
# Processing Record 10 of Set 4 | lavrentiya
# Processing Record 11 of Set 4 | kanbe
# Processing Record 12 of Set 4 | san patricio
# Processing Record 13 of Set 4 | ekibastuz
# Processing Record 14 of Set 4 | torbay
# Processing Record 15 of Set 4 | el badari
# City not found. Skipping...
# Processing Record 16 of Set 4 | asosa
# Processing Record 17 of Set 4 | roald
# Processing Record 18 of Set 4 | bathsheba
# Processing Record 19 of Set 4 | saint-philippe
# Processing Record 20 of Set 4 | namibe
# Processing Record 21 of Set 4 | visby
# Processing Record 22 of Set 4 | pisco
# Processing Record 23 of Set 4 | tono
# Processing Record 24 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 25 of Set 4 | mountain home
# Processing Record 26 of Set 4 | kalevala
# Processing Record 27 of Set 4 | komsomolskiy
# Processing Record 28 of Set 4 | trairi
# Processing Record 29 of Set 4 | ancud
# Processing Record 30 of Set 4 | elmira
# Processing Record 31 of Set 4 | verkhniye tatyshly
# Processing Record 32 of Set 4 | cidreira
# Processing Record 33 of Set 4 | san cristobal
# Processing Record 34 of Set 4 | maniitsoq
# Processing Record 35 of Set 4 | hobart
# Processing Record 36 of Set 4 | sobolevo
# Processing Record 37 of Set 4 | mao
# Processing Record 38 of Set 4 | byron bay
# Processing Record 39 of Set 4 | salinopolis
# Processing Record 40 of Set 4 | tura
# Processing Record 41 of Set 4 | constitucion
# Processing Record 42 of Set 4 | tevaitoa
# Processing Record 43 of Set 4 | taiyuan
# Processing Record 44 of Set 4 | beringovskiy
# Processing Record 45 of Set 4 | wewak
# Processing Record 46 of Set 4 | lebu
# Processing Record 47 of Set 4 | ardahan
# Processing Record 48 of Set 4 | peace river
# Processing Record 49 of Set 4 | vila velha
# Processing Record 50 of Set 4 | isangel
# Processing Record 1 of Set 5 | voyinka
# Processing Record 2 of Set 5 | puerto penasco
# Processing Record 3 of Set 5 | kysyl-syr
# Processing Record 4 of Set 5 | juarez
# Processing Record 5 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 6 of Set 5 | araouane
# Processing Record 7 of Set 5 | etne
# Processing Record 8 of Set 5 | hithadhoo
# Processing Record 9 of Set 5 | moranbah
# Processing Record 10 of Set 5 | katha
# City not found. Skipping...
# Processing Record 11 of Set 5 | haines junction
# Processing Record 12 of Set 5 | norman wells
# Processing Record 13 of Set 5 | mahanoro
# Processing Record 14 of Set 5 | puerto ayora
# Processing Record 15 of Set 5 | provideniya
# Processing Record 16 of Set 5 | tungor
# Processing Record 17 of Set 5 | tanabe
# Processing Record 18 of Set 5 | yellowknife
# Processing Record 19 of Set 5 | ntungamo
# Processing Record 20 of Set 5 | norilsk
# Processing Record 21 of Set 5 | chabahar
# Processing Record 22 of Set 5 | ugoofaaru
# Processing Record 23 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 5 | lagoa
# Processing Record 25 of Set 5 | yarada
# Processing Record 26 of Set 5 | mareeba
# Processing Record 27 of Set 5 | teeli
# Processing Record 28 of Set 5 | campos belos
# Processing Record 29 of Set 5 | xuddur
# Processing Record 30 of Set 5 | erzin
# Processing Record 31 of Set 5 | guerrero negro
# Processing Record 32 of Set 5 | college
# Processing Record 33 of Set 5 | buinsk
# Processing Record 34 of Set 5 | bethanien
# Processing Record 35 of Set 5 | kloulklubed
# Processing Record 36 of Set 5 | liverpool
# Processing Record 37 of Set 5 | plesoiu
# Processing Record 38 of Set 5 | lago da pedra
# Processing Record 39 of Set 5 | santa isabel
# Processing Record 40 of Set 5 | cururupu
# Processing Record 41 of Set 5 | kinango
# Processing Record 42 of Set 5 | la ronge
# Processing Record 43 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 44 of Set 5 | tilichiki
# Processing Record 45 of Set 5 | east london
# Processing Record 46 of Set 5 | half moon bay
# Processing Record 47 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 5 | floro
# Processing Record 49 of Set 5 | shimizu
# Processing Record 50 of Set 5 | tautira
# Processing Record 1 of Set 6 | cap malheureux
# Processing Record 2 of Set 6 | grand-santi
# Processing Record 3 of Set 6 | necochea
# Processing Record 4 of Set 6 | chara
# Processing Record 5 of Set 6 | kargil
# Processing Record 6 of Set 6 | penarroya-pueblonuevo
# Processing Record 7 of Set 6 | new norfolk
# Processing Record 8 of Set 6 | ivajlovgrad
# City not found. Skipping...
# Processing Record 9 of Set 6 | sault sainte marie
# Processing Record 10 of Set 6 | vostok
# Processing Record 11 of Set 6 | talcahuano
# Processing Record 12 of Set 6 | salalah
# Processing Record 13 of Set 6 | ziarat
# Processing Record 14 of Set 6 | barabinsk
# Processing Record 15 of Set 6 | fairbanks
# Processing Record 16 of Set 6 | faanui
# Processing Record 17 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 6 | marrakesh
# Processing Record 19 of Set 6 | te anau
# Processing Record 20 of Set 6 | yei
# Processing Record 21 of Set 6 | piacabucu
# Processing Record 22 of Set 6 | mango
# Processing Record 23 of Set 6 | capoterra
# Processing Record 24 of Set 6 | ixtapa
# Processing Record 25 of Set 6 | san carlos de bariloche
# Processing Record 26 of Set 6 | belaya gora
# Processing Record 27 of Set 6 | dunmore town
# Processing Record 28 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 6 | zhigansk
# Processing Record 30 of Set 6 | sitka
# Processing Record 31 of Set 6 | baracoa
# Processing Record 32 of Set 6 | lukovetskiy
# Processing Record 33 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 6 | talnakh
# Processing Record 35 of Set 6 | alofi
# Processing Record 36 of Set 6 | qui nhon
# Processing Record 37 of Set 6 | maceio
# Processing Record 38 of Set 6 | gulu
# Processing Record 39 of Set 6 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 6 | nampula
# Processing Record 41 of Set 6 | morelia
# Processing Record 42 of Set 6 | bubaque
# Processing Record 43 of Set 6 | fortuna
# Processing Record 44 of Set 6 | comodoro rivadavia
# Processing Record 45 of Set 6 | babstovo
# Processing Record 46 of Set 6 | praya
# Processing Record 47 of Set 6 | cruzeiro do sul
# Processing Record 48 of Set 6 | kaputa
# Processing Record 49 of Set 6 | coihaique
# Processing Record 50 of Set 6 | mayo
# Processing Record 1 of Set 7 | vestmannaeyjar
# Processing Record 2 of Set 7 | moshenskoye
# Processing Record 3 of Set 7 | rio grande
# Processing Record 4 of Set 7 | fort walton beach
# Processing Record 5 of Set 7 | dingle
# Processing Record 6 of Set 7 | sao filipe
# Processing Record 7 of Set 7 | ende
# Processing Record 8 of Set 7 | cairns
# Processing Record 9 of Set 7 | nanakuli
# Processing Record 10 of Set 7 | severnyy-kospashskiy
# Processing Record 11 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 7 | illapel
# Processing Record 13 of Set 7 | berlevag
# Processing Record 14 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 15 of Set 7 | muros
# Processing Record 16 of Set 7 | nome
# Processing Record 17 of Set 7 | eloi mendes
# Processing Record 18 of Set 7 | cariamanga
# Processing Record 19 of Set 7 | ajaccio
# Processing Record 20 of Set 7 | galesong
# Processing Record 21 of Set 7 | taoudenni
# Processing Record 22 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 7 | victor harbor
# Processing Record 24 of Set 7 | gazanjyk
# Processing Record 25 of Set 7 | mogapinyana
# Processing Record 26 of Set 7 | vestmanna
# Processing Record 27 of Set 7 | bushehr
# Processing Record 28 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 7 | praia da vitoria
# Processing Record 30 of Set 7 | florida
# Processing Record 31 of Set 7 | upernavik
# Processing Record 32 of Set 7 | borovoy
# Processing Record 33 of Set 7 | sakaiminato
# Processing Record 34 of Set 7 | jardim
# Processing Record 35 of Set 7 | esna
# Processing Record 36 of Set 7 | wajid
# Processing Record 37 of Set 7 | marevo
# Processing Record 38 of Set 7 | georgetown
# Processing Record 39 of Set 7 | lar
# Processing Record 40 of Set 7 | burevestnik
# Processing Record 41 of Set 7 | viedma
# Processing Record 42 of Set 7 | souillac
# Processing Record 43 of Set 7 | grand gaube
# Processing Record 44 of Set 7 | negara
# Processing Record 45 of Set 7 | tessalit
# Processing Record 46 of Set 7 | khani
# Processing Record 47 of Set 7 | atar
# Processing Record 48 of Set 7 | sola
# Processing Record 49 of Set 7 | boa vista
# Processing Record 50 of Set 7 | shimoda
# Processing Record 1 of Set 8 | ahipara
# Processing Record 2 of Set 8 | banda aceh
# Processing Record 3 of Set 8 | freeport
# Processing Record 4 of Set 8 | itoman
# Processing Record 5 of Set 8 | husavik
# Processing Record 6 of Set 8 | tucumcari
# Processing Record 7 of Set 8 | coquimbo
# Processing Record 8 of Set 8 | pevek
# Processing Record 9 of Set 8 | bousso
# Processing Record 10 of Set 8 | port macquarie
# Processing Record 11 of Set 8 | omboue
# Processing Record 12 of Set 8 | ankara
# Processing Record 13 of Set 8 | longyearbyen
# Processing Record 14 of Set 8 | kodiak
# Processing Record 15 of Set 8 | bambous virieux
# Processing Record 16 of Set 8 | mishan
# Processing Record 17 of Set 8 | arani
# Processing Record 18 of Set 8 | opuwo
# Processing Record 19 of Set 8 | sao joao da barra
# Processing Record 20 of Set 8 | dunedin
# Processing Record 21 of Set 8 | bafra
# Processing Record 22 of Set 8 | kapuskasing
# Processing Record 23 of Set 8 | sao felix do xingu
# Processing Record 24 of Set 8 | hamilton
# Processing Record 25 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 8 | arsk
# Processing Record 27 of Set 8 | wote
# Processing Record 28 of Set 8 | dawlatabad
# Processing Record 29 of Set 8 | saint-pierre
# Processing Record 30 of Set 8 | san juan nepomuceno
# Processing Record 31 of Set 8 | bandarbeyla
# Processing Record 32 of Set 8 | kodinsk
# Processing Record 33 of Set 8 | cabimas
# Processing Record 34 of Set 8 | privokzalnyy
# City not found. Skipping...
# Processing Record 35 of Set 8 | hobyo
# Processing Record 36 of Set 8 | kabalo
# Processing Record 37 of Set 8 | kaseda
# Processing Record 38 of Set 8 | biltine
# Processing Record 39 of Set 8 | tagusao
# Processing Record 40 of Set 8 | takoradi
# Processing Record 41 of Set 8 | rio casca
# Processing Record 42 of Set 8 | bindi
# Processing Record 43 of Set 8 | beisfjord
# Processing Record 44 of Set 8 | urengoy
# Processing Record 45 of Set 8 | nagareyama
# Processing Record 46 of Set 8 | kakching
# Processing Record 47 of Set 8 | tual
# Processing Record 48 of Set 8 | danilovka
# Processing Record 49 of Set 8 | ternate
# Processing Record 50 of Set 8 | victoria
# Processing Record 1 of Set 9 | nadym
# Processing Record 2 of Set 9 | krasnoselkup
# Processing Record 3 of Set 9 | lagos
# Processing Record 4 of Set 9 | haukipudas
# Processing Record 5 of Set 9 | vizinga
# Processing Record 6 of Set 9 | karratha
# Processing Record 7 of Set 9 | la paz
# Processing Record 8 of Set 9 | walla walla
# Processing Record 9 of Set 9 | yatou
# Processing Record 10 of Set 9 | marawi
# Processing Record 11 of Set 9 | linxia
# Processing Record 12 of Set 9 | fountain
# Processing Record 13 of Set 9 | port-gentil
# Processing Record 14 of Set 9 | piastow
# Processing Record 15 of Set 9 | martapura
# Processing Record 16 of Set 9 | havre-saint-pierre
# Processing Record 17 of Set 9 | san luis
# Processing Record 18 of Set 9 | hofn
# Processing Record 19 of Set 9 | athabasca
# Processing Record 20 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 9 | kushiro
# Processing Record 22 of Set 9 | amapa
# Processing Record 23 of Set 9 | maragogi
# Processing Record 24 of Set 9 | vanimo
# Processing Record 25 of Set 9 | nizhniy odes
# Processing Record 26 of Set 9 | doha
# Processing Record 27 of Set 9 | gazojak
# Processing Record 28 of Set 9 | ossora
# Processing Record 29 of Set 9 | mtambile
# Processing Record 30 of Set 9 | nuevo progreso
# Processing Record 31 of Set 9 | haikou
# Processing Record 32 of Set 9 | changtu
# Processing Record 33 of Set 9 | la asuncion
# Processing Record 34 of Set 9 | northam
# Processing Record 35 of Set 9 | san jeronimo
# Processing Record 36 of Set 9 | salina
# Processing Record 37 of Set 9 | kahului
# Processing Record 38 of Set 9 | morondava
# Processing Record 39 of Set 9 | mitchell
# Processing Record 40 of Set 9 | gold coast
# Processing Record 41 of Set 9 | tupik
# Processing Record 42 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 9 | bogdand
# Processing Record 44 of Set 9 | sherman
# Processing Record 45 of Set 9 | scarborough
# Processing Record 46 of Set 9 | berbera
# Processing Record 47 of Set 9 | portobelo
# Processing Record 48 of Set 9 | aleksandrov gay
# Processing Record 49 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 50 of Set 9 | ilulissat
# Processing Record 1 of Set 10 | port hawkesbury
# Processing Record 2 of Set 10 | bereda
# Processing Record 3 of Set 10 | klaksvik
# Processing Record 4 of Set 10 | katobu
# Processing Record 5 of Set 10 | verkhoyansk
# Processing Record 6 of Set 10 | kasane
# Processing Record 7 of Set 10 | lorengau
# Processing Record 8 of Set 10 | port augusta
# Processing Record 9 of Set 10 | mirnyy
# Processing Record 10 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 10 | talaya
# Processing Record 12 of Set 10 | santa maria
# Processing Record 13 of Set 10 | takaka
# Processing Record 14 of Set 10 | abu jubayhah
# City not found. Skipping...
# Processing Record 15 of Set 10 | millinocket
# Processing Record 16 of Set 10 | nouadhibou
# Processing Record 17 of Set 10 | saint anthony
# Processing Record 18 of Set 10 | sayansk
# Processing Record 19 of Set 10 | palanit
# Processing Record 20 of Set 10 | azuaga
# Processing Record 21 of Set 10 | olafsvik
# Processing Record 22 of Set 10 | bilma
# Processing Record 23 of Set 10 | alice springs
# Processing Record 24 of Set 10 | tazovskiy
# Processing Record 25 of Set 10 | kuzovatovo
# Processing Record 26 of Set 10 | basco
# Processing Record 27 of Set 10 | ust-kuyga
# Processing Record 28 of Set 10 | ambon
# Processing Record 29 of Set 10 | pionerskiy
# Processing Record 30 of Set 10 | tank
# Processing Record 31 of Set 10 | stornoway
# Processing Record 32 of Set 10 | felanitx
# Processing Record 33 of Set 10 | rognan
# Processing Record 34 of Set 10 | kwidzyn
# Processing Record 35 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 36 of Set 10 | petrolina
# Processing Record 37 of Set 10 | nishihara
# Processing Record 38 of Set 10 | usogorsk
# Processing Record 39 of Set 10 | waingapu
# Processing Record 40 of Set 10 | brawley
# Processing Record 41 of Set 10 | torhout
# Processing Record 42 of Set 10 | saryg-sep
# Processing Record 43 of Set 10 | ambilobe
# Processing Record 44 of Set 10 | nhulunbuy
# Processing Record 45 of Set 10 | pecos
# Processing Record 46 of Set 10 | makakilo city
# Processing Record 47 of Set 10 | yudong
# Processing Record 48 of Set 10 | pizarro
# Processing Record 49 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 10 | santa cruz del sur
# Processing Record 1 of Set 11 | sisimiut
# Processing Record 2 of Set 11 | nicoya
# Processing Record 3 of Set 11 | porto velho
# Processing Record 4 of Set 11 | falkensee
# Processing Record 5 of Set 11 | brae
# Processing Record 6 of Set 11 | ucluelet
# Processing Record 7 of Set 11 | moron
# Processing Record 8 of Set 11 | moiyabana
# City not found. Skipping...
# Processing Record 9 of Set 11 | tete
# Processing Record 10 of Set 11 | aykhal
# Processing Record 11 of Set 11 | sheltozero
# Processing Record 12 of Set 11 | matara
# Processing Record 13 of Set 11 | avera
# Processing Record 14 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 15 of Set 11 | polunochnoye
# Processing Record 16 of Set 11 | miranda
# Processing Record 17 of Set 11 | carutapera
# Processing Record 18 of Set 11 | bontang
# Processing Record 19 of Set 11 | wageningen
# Processing Record 20 of Set 11 | marsh harbour
# Processing Record 21 of Set 11 | rincon
# Processing Record 22 of Set 11 | wonthaggi
# Processing Record 23 of Set 11 | collie
# Processing Record 24 of Set 11 | karakol
# Processing Record 25 of Set 11 | nioro
# Processing Record 26 of Set 11 | gat
# Processing Record 27 of Set 11 | pathein
# Processing Record 28 of Set 11 | bolobo
# Processing Record 29 of Set 11 | swift current
# Processing Record 30 of Set 11 | sangin
# Processing Record 31 of Set 11 | dualing
# Processing Record 32 of Set 11 | elizabeth city
# Processing Record 33 of Set 11 | sfantu gheorghe
# Processing Record 34 of Set 11 | joniskelis
# Processing Record 35 of Set 11 | pingliang
# Processing Record 36 of Set 11 | mubende
# Processing Record 37 of Set 11 | methoni
# Processing Record 38 of Set 11 | asau
# Processing Record 39 of Set 11 | uvarovo
# Processing Record 40 of Set 11 | great yarmouth
# Processing Record 41 of Set 11 | indianola
# Processing Record 42 of Set 11 | marzuq
# Processing Record 43 of Set 11 | dong hoi
# Processing Record 44 of Set 11 | burkhala
# City not found. Skipping...
# Processing Record 45 of Set 11 | puerto del rosario
# Processing Record 46 of Set 11 | yurla
# Processing Record 47 of Set 11 | nsanje
# Processing Record 48 of Set 11 | pontes e lacerda
# Processing Record 49 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 50 of Set 11 | san francisco
# Processing Record 1 of Set 12 | dera bugti
# Processing Record 2 of Set 12 | morros
# Processing Record 3 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 4 of Set 12 | lyngseidet
# Processing Record 5 of Set 12 | dzaoudzi
# Processing Record 6 of Set 12 | vega de alatorre
# Processing Record 7 of Set 12 | umea
# Processing Record 8 of Set 12 | bowen
# Processing Record 9 of Set 12 | seoul
# Processing Record 10 of Set 12 | port saint lucie
# Processing Record 11 of Set 12 | lensk
# Processing Record 12 of Set 12 | keningau
# Processing Record 13 of Set 12 | hoquiam
# Processing Record 14 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 12 | jinxiang
# Processing Record 16 of Set 12 | mastung
# Processing Record 17 of Set 12 | san matias
# Processing Record 18 of Set 12 | wana
# Processing Record 19 of Set 12 | saint-felix-de-valois
# Processing Record 20 of Set 12 | turukhansk
# Processing Record 21 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 12 | rokytne
# Processing Record 23 of Set 12 | kismayo
# Processing Record 24 of Set 12 | ozark
# Processing Record 25 of Set 12 | druzhba
# Processing Record 26 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 27 of Set 12 | luba
# Processing Record 28 of Set 12 | along
# Processing Record 29 of Set 12 | zacualpan
# Processing Record 30 of Set 12 | parthenay
# Processing Record 31 of Set 12 | cuiluan
# Processing Record 32 of Set 12 | leca da palmeira
# Processing Record 33 of Set 12 | port lincoln
# Processing Record 34 of Set 12 | riyadh
# Processing Record 35 of Set 12 | starotimoshkino
# Processing Record 36 of Set 12 | tambopata
# Processing Record 37 of Set 12 | waraseoni
# Processing Record 38 of Set 12 | jalu
# Processing Record 39 of Set 12 | oktyabrskiy
# Processing Record 40 of Set 12 | pangnirtung
# Processing Record 41 of Set 12 | malakal
# Processing Record 42 of Set 12 | dutlwe
# Processing Record 43 of Set 12 | ulladulla
# Processing Record 44 of Set 12 | bhag
# Processing Record 45 of Set 12 | gitarama
# Processing Record 46 of Set 12 | lasa
# Processing Record 47 of Set 12 | eidsvag
# Processing Record 48 of Set 12 | bata
# Processing Record 49 of Set 12 | terrace
# Processing Record 50 of Set 12 | narsaq
# Processing Record 1 of Set 13 | leh
# Processing Record 2 of Set 13 | tarapur
# Processing Record 3 of Set 13 | san quintin
# Processing Record 4 of Set 13 | namatanai
# Processing Record 5 of Set 13 | arica
# Processing Record 6 of Set 13 | cape elizabeth
# City not found. Skipping...
# Processing Record 7 of Set 13 | huangnihe
# Processing Record 8 of Set 13 | oyama
# Processing Record 9 of Set 13 | ouadda
# Processing Record 10 of Set 13 | mangrol
# Processing Record 11 of Set 13 | aswan
# Processing Record 12 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 13 of Set 13 | derzhavinsk
# Processing Record 14 of Set 13 | hervey bay
# Processing Record 15 of Set 13 | gourdon
# Processing Record 16 of Set 13 | batagay
# Processing Record 17 of Set 13 | alamosa
# Processing Record 18 of Set 13 | midland
# Processing Record 19 of Set 13 | ceska lipa
# Processing Record 20 of Set 13 | surigao
# Processing Record 21 of Set 13 | adrar
# Processing Record 22 of Set 13 | loviisa
# Processing Record 23 of Set 13 | tymovskoye
# Processing Record 24 of Set 13 | tarakan
# Processing Record 25 of Set 13 | urussu
# Processing Record 26 of Set 13 | hualmay
# Processing Record 27 of Set 13 | balakovo
# Processing Record 28 of Set 13 | yaring
# Processing Record 29 of Set 13 | eyemouth
# Processing Record 30 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 13 | acapulco
# Processing Record 32 of Set 13 | sorland
# Processing Record 33 of Set 13 | bonthe
# Processing Record 34 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 35 of Set 13 | pilao arcado
# City not found. Skipping...
# Processing Record 36 of Set 13 | kishi
# Processing Record 37 of Set 13 | wad madani
# Processing Record 38 of Set 13 | broken hill
# Processing Record 39 of Set 13 | huarmey
# Processing Record 40 of Set 13 | luanda
# Processing Record 41 of Set 13 | jumla
# Processing Record 42 of Set 13 | yenagoa
# Processing Record 43 of Set 13 | madang
# Processing Record 44 of Set 13 | ishigaki
# Processing Record 45 of Set 13 | matagami
# Processing Record 46 of Set 13 | ashland
# Processing Record 47 of Set 13 | deputatskiy
# Processing Record 48 of Set 13 | chumikan
# Processing Record 49 of Set 13 | arlit
# Processing Record 50 of Set 13 | bojnurd
# Processing Record 1 of Set 14 | requena
# Processing Record 2 of Set 14 | cravo norte
# Processing Record 3 of Set 14 | anchorage
# Processing Record 4 of Set 14 | chivay
# Processing Record 5 of Set 14 | poya
# Processing Record 6 of Set 14 | oxapampa
# Processing Record 7 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 8 of Set 14 | nikel
# Processing Record 9 of Set 14 | katherine
# Processing Record 10 of Set 14 | pimentel
# Processing Record 11 of Set 14 | homer
# Processing Record 12 of Set 14 | pangoa
# Processing Record 13 of Set 14 | manjacaze
# Processing Record 14 of Set 14 | formosa
# Processing Record 15 of Set 14 | campbell river
# Processing Record 16 of Set 14 | taltal
# Processing Record 17 of Set 14 | tiparak
# Processing Record 18 of Set 14 | veraval
# Processing Record 19 of Set 14 | arman
# Processing Record 20 of Set 14 | tarazona
# Processing Record 21 of Set 14 | nelson bay
# Processing Record 22 of Set 14 | dickinson
# Processing Record 23 of Set 14 | solnechnyy
# Processing Record 24 of Set 14 | potiskum
# Processing Record 25 of Set 14 | okhotsk
# Processing Record 26 of Set 14 | baykit
# Processing Record 27 of Set 14 | kelowna
# Processing Record 28 of Set 14 | storm lake
# Processing Record 29 of Set 14 | naze
# Processing Record 30 of Set 14 | kingsport
# Processing Record 31 of Set 14 | saint-louis
# Processing Record 32 of Set 14 | andenes
# Processing Record 33 of Set 14 | wakema
# Processing Record 34 of Set 14 | rocha
# Processing Record 35 of Set 14 | clyde river
# Processing Record 36 of Set 14 | weihe
# Processing Record 37 of Set 14 | grafton
# Processing Record 38 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 14 | smithers
# Processing Record 40 of Set 14 | saurimo
# Processing Record 41 of Set 14 | nakambala
# Processing Record 42 of Set 14 | sept-iles
# Processing Record 43 of Set 14 | yuzhno-kurilsk
# Processing Record 44 of Set 14 | prince george
# Processing Record 45 of Set 14 | staraya poltavka
# Processing Record 46 of Set 14 | lincoln
# Processing Record 47 of Set 14 | tucurui
# Processing Record 48 of Set 14 | ornskoldsvik
# Processing Record 49 of Set 14 | dali
# Processing Record 50 of Set 14 | kaduna
# Processing Record 1 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 15 | roma
# Processing Record 3 of Set 15 | iwamizawa
# Processing Record 4 of Set 15 | chiredzi
# Processing Record 5 of Set 15 | victoria point
# Processing Record 6 of Set 15 | wanaka
# Processing Record 7 of Set 15 | cedar city
# Processing Record 8 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 15 | san andres
# Processing Record 10 of Set 15 | malangali
# Processing Record 11 of Set 15 | yar-sale
# Processing Record 12 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 13 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 15 of Set 15 | sayyan
# Processing Record 16 of Set 15 | awjilah
# Processing Record 17 of Set 15 | isilkul
# Processing Record 18 of Set 15 | saint-joseph
# Processing Record 19 of Set 15 | zambezi
# Processing Record 20 of Set 15 | kamaishi
# Processing Record 21 of Set 15 | miri
# Processing Record 22 of Set 15 | mentok
# City not found. Skipping...
# Processing Record 23 of Set 15 | sain alto
# Processing Record 24 of Set 15 | halifax
# Processing Record 25 of Set 15 | egvekinot
# Processing Record 26 of Set 15 | tyrma
# Processing Record 27 of Set 15 | flin flon
# Processing Record 28 of Set 15 | vaitape
# Processing Record 29 of Set 15 | brufut
# Processing Record 30 of Set 15 | teya
# Processing Record 31 of Set 15 | kon tum
# Processing Record 32 of Set 15 | popondetta
# Processing Record 33 of Set 15 | teahupoo
# Processing Record 34 of Set 15 | albanel
# Processing Record 35 of Set 15 | kulhudhuffushi
# Processing Record 36 of Set 15 | nuevitas
# Processing Record 37 of Set 15 | mattru
# Processing Record 38 of Set 15 | koshurnikovo
# Processing Record 39 of Set 15 | petrovskoye
# Processing Record 40 of Set 15 | sinnamary
# Processing Record 41 of Set 15 | padang
# Processing Record 42 of Set 15 | paz de ariporo
# City not found. Skipping...
# Processing Record 43 of Set 15 | kavarna
# Processing Record 44 of Set 15 | dorado
# Processing Record 45 of Set 15 | dingli
# Processing Record 46 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 47 of Set 15 | fayaoue
# Processing Record 48 of Set 15 | felipe carrillo puerto
# Processing Record 49 of Set 15 | oranjemund
# Processing Record 50 of Set 15 | dumai
# Processing Record 1 of Set 16 | warmbad
# Processing Record 2 of Set 16 | rawson
# Processing Record 3 of Set 16 | lamar
# Processing Record 4 of Set 16 | mirganj
# Processing Record 5 of Set 16 | iquitos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 695

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany      US  42.6001  -73.9662      9.00        59          17
# 1     Semenivka      UA  52.1783   32.5818     24.84        97          93
# 2        Palmer      US  42.1584  -72.3287      6.80        66           1
# 3       Rikitea      PF -23.1203 -134.9692     78.55        77          44
# 4       Ushuaia      AR -54.8000  -68.3000     48.20        61          75
# 5         Kapaa      US  22.0752 -159.3190     72.00        88          75
# 6     Itanhandu      BR -22.2958  -44.9347     64.51        87          58
# 7  Punta Arenas      CL -53.1500  -70.9167     46.40        81           0
# 8          Paka      MY   4.6374  103.4368     80.60        83          40
# 9           Sur      OM  22.5667   59.5289     77.07        40           0
#
#    Wind Speed Current Conditions
# 0        3.36         few clouds
# 1       13.13    overcast clouds
# 2        4.61          clear sky
# 3       10.40         light rain
# 4        9.22      broken clouds
# 5       17.27         light rain
# 6        1.01      broken clouds
# 7       12.66          clear sky
# 8        9.22   scattered clouds
# 9        6.40          clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
